# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Conference Room

# %%
# Import data to pandas dataframe
import pandas as pd

data_dir = '../data/preprocessed/'

# Load dataframe
df_conference_room = pd.read_csv(data_dir + 'conference_room.csv')
df_conference_room.drop(['index'], axis=1, inplace=True)
df_conference_room.head(10)
# Out:
#           sim  tem  mass   n   w   s  sw   e  ew  floor  ceiling  n occ    x  \
# 0       dummy   21  0.29  26  26  27  26  26  26     26       26      3  3.6
# 1      column   21  0.29  25  26  26  28  26  26     25       25      3  3.6
# 2  for python   24  0.08  20  20  20  12  19  12     20       20      3  3.6
# 3          to   14  0.07  22  23  20  19  20  19     21       21      3  3.6
# 4         run   14  0.19  26  27  28  34  28  30     27       27      3  3.6
# 5    properly   13  0.21  26  27  27  28  28  31     27       27      3  3.6
# 6           6   19  0.03  24  25  22  21  22  25     23       23      3  3.6
# 7           7   16  0.31  26  27  29  32  28  26     27       27      3  3.6
# 8           8   13  0.05  25  26  27  25  26  21     24       24      3  3.6
# 9           9   15  0.13  25  25  26  25  26  25     25       25      3  3.6
#
#      y        MRT          T         V
# 0  4.3  26.848456  24.436355  0.244356
# 1  4.3  26.158878  24.108097  0.220350
# ...

# %%
import matplotlib.pyplot as plt

# Show features' distribution graph
fig, ax = plt.subplots(figsize=(20,15))
df_conference_room.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_conference_room.png')
# Out:
# /tmp/ipykernel_115560/1564333252.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_conference_room.hist(bins=50, ax=ax)

# %%
# Show features' distribution graph without MRT, T, V
df_conference_room_dropped = df_conference_room.drop(['MRT', 'T', 'V'], axis=1)
fig, ax = plt.subplots(figsize=(20,15))
df_conference_room_dropped.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_conference_room_dropped.png')
# Out:
# /tmp/ipykernel_115560/1092462008.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_conference_room_dropped.hist(bins=50, ax=ax)

# %%
import seaborn as sn

# Show features' correlation graph
corrMatrix = df_conference_room.corr()
plt.figure(figsize = (20,10))
svm = sn.heatmap(corrMatrix, annot=True)
fig = svm.get_figure()
plt.show()
fig.savefig('../figures/heatmap_conference_room.png')

# %% [markdown]
# # Enclosed Office

# %%
# Load dataframe
df_enclosed_office = pd.read_csv(data_dir + 'enclosed_office-w_valid.csv')
df_enclosed_office.drop(['index'], axis=1, inplace=True)
df_enclosed_office.head(10)
# Out:
#    sim      mass  tem_supply  tem_surf   tem_win  tem_int  n_occ     x     y  \
# 0    0  0.023125   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 1    1  0.057814   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 2    2  0.173441   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 3    3  0.023125   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 4    4  0.057814   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 5    5  0.173441   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 6    6  0.023125   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 7    7  0.057814   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 8    8  0.173441   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 9    9  0.023125   26.666667  7.222222 -1.111111    26.85      1  2.05  2.25
#
#          MRT          T         V
# 0  26.186008  27.351396  0.079308
# 1  26.522128  27.722396  0.071792
# ...

# %%
# Show features' distribution graph
fig, ax = plt.subplots(figsize=(20,15))
df_enclosed_office.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_enclosed_office-w_valid.png')
# Out:
# /tmp/ipykernel_115560/3336570593.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_enclosed_office.hist(bins=50, ax=ax)

# %%
# Show features' distribution graph without MRT, T, V
df_enclosed_office_dropped = df_enclosed_office.drop(['MRT', 'T', 'V'], axis=1)
fig, ax = plt.subplots(figsize=(20,15))
df_enclosed_office_dropped.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_enclosed_office_dropped.png')
# Out:
# /tmp/ipykernel_115560/2090409164.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_enclosed_office_dropped.hist(bins=50, ax=ax)

# %%
# Show features' correlation graph
corrMatrix = df_enclosed_office.corr()
plt.figure(figsize = (20,10))
svm = sn.heatmap(corrMatrix, annot=True)
fig = svm.get_figure()
plt.show()
fig.savefig('../figures/heatmap_enclosed_office-w_valid.png')

# %% [markdown]
# # Enclosed Office with Validation

# %%
# Load dataframe
df_enclosed_office = pd.read_csv(data_dir + 'enclosed_office-w_valid.csv')
df_enclosed_office.drop(['index'], axis=1, inplace=True)
df_enclosed_office.head(10)
# Out:
#    sim      mass  tem_supply  tem_surf   tem_win  tem_int  n_occ     x     y  \
# 0    0  0.023125   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 1    1  0.057814   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 2    2  0.173441   26.666667  4.444444 -1.111111    26.85      1  2.05  2.25
# 3    3  0.023125   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 4    4  0.057814   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 5    5  0.173441   29.444444  4.444444 -1.111111    26.85      1  2.05  2.25
# 6    6  0.023125   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 7    7  0.057814   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 8    8  0.173441   35.000000  4.444444 -1.111111    26.85      1  2.05  2.25
# 9    9  0.023125   26.666667  7.222222 -1.111111    26.85      1  2.05  2.25
#
#          MRT          T         V
# 0  26.186008  27.351396  0.079308
# 1  26.522128  27.722396  0.071792
# ...

# %%
# Show features' distribution graph
fig, ax = plt.subplots(figsize=(20,15))
df_enclosed_office.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_enclosed_office-w_valid.png')
# Out:
# /tmp/ipykernel_115560/3336570593.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_enclosed_office.hist(bins=50, ax=ax)

# %%
# Show features' distribution graph without MRT, T, V
df_enclosed_office_dropped = df_enclosed_office.drop(['MRT', 'T', 'V'], axis=1)
fig, ax = plt.subplots(figsize=(20,15))
df_enclosed_office_dropped.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_enclosed_office-w_valid_dropped.png')
# Out:
# /tmp/ipykernel_115560/2645840552.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_enclosed_office_dropped.hist(bins=50, ax=ax)

# %%
# Show features' correlation graph
corrMatrix = df_enclosed_office.corr()
plt.figure(figsize = (20,10))
svm = sn.heatmap(corrMatrix, annot=True)
fig = svm.get_figure()
plt.show()
fig.savefig('../figures/heatmap_enclosed_office-w_valid.png')

# %% [markdown]
# # Open Office

# %%
# Load dataframe
df_open_office = pd.read_csv(data_dir + 'open_office.csv')
df_open_office.drop(['index'], axis=1, inplace=True)
df_open_office.head(10)
# Out:
#    sim  tem  mass   n  occ       x    y        MRT          T         V
# 0    0   15    26  24    3   7.185  5.8  25.637628  25.047852  0.076857
# 1    0   15    26  24    3  10.185  3.8  25.742467  25.287418  0.077991
# 2    0   15    26  24    3  13.175  5.8  25.770578  25.173074  0.081802
# 3    1   17     1  23    3   7.185  5.8  24.486969  22.068668  0.098301
# 4    1   17     1  23    3  10.185  3.8  24.506978  22.030342  0.114596
# 5    1   17     1  23    3  13.175  5.8  24.510649  21.756448  0.103460
# 6    2   17    11  23    3   7.185  5.8  24.602400  22.872866  0.095697
# 7    2   17    11  23    3  10.185  3.8  24.656361  22.904818  0.105776
# 8    2   17    11  23    3  13.175  5.8  24.685113  22.879714  0.093277
# 9    3   13    23  25    3   7.185  5.8  26.490313  25.763345  0.074024

# %%
# Show features' distribution graph
fig, ax = plt.subplots(figsize=(20,15))
df_open_office.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_open_office.png')
# Out:
# /tmp/ipykernel_115560/596907391.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_open_office.hist(bins=50, ax=ax)

# %%
# Show features' distribution graph without MRT, T, V
df_open_office_dropped = df_open_office.drop(['MRT', 'T', 'V'], axis=1)
fig, ax = plt.subplots(figsize=(20,15))
df_open_office_dropped.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_open_office_dropped.png')
# Out:
# /tmp/ipykernel_115560/2276142653.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_open_office_dropped.hist(bins=50, ax=ax)

# %%
# Show features' correlation graph
corrMatrix = df_open_office.corr()
plt.figure(figsize = (20,10))
svm = sn.heatmap(corrMatrix, annot=True)
fig = svm.get_figure()
plt.show()
fig.savefig('../figures/heatmap_open_office.png')

# %% [markdown]
# # Small Office

# %%
# Load dataframe
df_small_office = pd.read_csv(data_dir + 'small_office.csv')
df_small_office.drop(['index'], axis=1, inplace=True)
df_small_office.head(10)
# Out:
#    sim       saf   sat    ewt    ist     wit  n_occ        x      y  \
# 0    1  0.393132  4.44  23.89  23.89  24.584      3   9.2300  1.575
# 1    1  0.393132  4.44  23.89  23.89  24.584      3   6.9225  3.425
# 2    1  0.393132  4.44  23.89  23.89  24.584      3  20.7675  3.425
# 3    2  0.393132  4.44  23.89  23.89  26.112      3   9.2300  1.575
# 4    2  0.393132  4.44  23.89  23.89  26.112      3   6.9225  3.425
# 5    2  0.393132  4.44  23.89  23.89  26.112      3  20.7675  3.425
# 6    3  0.393132  4.44  23.89  23.89  27.501      3   9.2300  1.575
# 7    3  0.393132  4.44  23.89  23.89  27.501      3   6.9225  3.425
# 8    3  0.393132  4.44  23.89  23.89  27.501      3  20.7675  3.425
# 9    4  0.393132  4.44  25.97  25.97  24.584      3   9.2300  1.575
#
#          MRT          T         V
# 0  24.989951  21.893177  0.134302
# 1  24.968407  21.683336  0.157072
# 2  24.891787  21.696797  0.196306
# 3  25.019500  21.946554  0.140809
# 4  25.020847  21.658083  0.152841
# ...

# %%
# Show features' distribution graph without MRT, T, V
df_small_office_dropped = df_small_office.drop(['MRT', 'T', 'V'], axis=1)
fig, ax = plt.subplots(figsize=(20,15))
df_small_office_dropped.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_small_office_dropped.png')
# Out:
# /tmp/ipykernel_115560/4082375906.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_small_office_dropped.hist(bins=50, ax=ax)

# %%
# Show features' distribution graph
fig, ax = plt.subplots(figsize=(20,15))
df_small_office.hist(bins=50, ax=ax)
fig.savefig('../figures/hist_small_office.png')
# Out:
# /tmp/ipykernel_115560/4072246879.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_small_office.hist(bins=50, ax=ax)

# %%
# Show features' correlation graph
corrMatrix = df_small_office.corr()
plt.figure(figsize = (20,10))
svm = sn.heatmap(corrMatrix, annot=True)
fig = svm.get_figure()
plt.show()
fig.savefig('../figures/heatmap_small_office.png')
