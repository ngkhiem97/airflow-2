# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Conference Room

# %%
# Import data to pandas dataframe
import pandas as pd

data_dir = '../data/preprocessed/'

# Concatenate dataframes' columns
df = pd.read_csv(data_dir + 'conference_room.csv')

df.head(10)
# Out:
#    Unnamed: 0  index         sim  tem  mass   n   w   s  sw   e  ew  floor  \
# 0           0      0       dummy   21  0.29  26  26  27  26  26  26     26
# 1           1      1      column   21  0.29  25  26  26  28  26  26     25
# 2           2      2  for python   24  0.08  20  20  20  12  19  12     20
# 3           3      3          to   14  0.07  22  23  20  19  20  19     21
# 4           4      4         run   14  0.19  26  27  28  34  28  30     27
# 5           5      5    properly   13  0.21  26  27  27  28  28  31     27
# 6           6      6           6   19  0.03  24  25  22  21  22  25     23
# 7           7      7           7   16  0.31  26  27  29  32  28  26     27
# 8           8      8           8   13  0.05  25  26  27  25  26  21     24
# 9           9      9           9   15  0.13  25  25  26  25  26  25     25
#
#    ceiling  n occ    x    y        MRT          T         V
# 0       26      3  3.6  4.3  26.848456  24.436355  0.244356
# 1       25      3  3.6  4.3  26.158878  24.108097  0.220350
# 2       20      3  3.6  4.3  21.018701  20.254636  0.081578
# 3       21      3  3.6  4.3  22.559423  20.568076  0.104254
# 4       27      3  3.6  4.3  27.814494  24.417741  0.145479
# 5       27      3  3.6  4.3  27.623200  23.451016  0.160609
# 6       23      3  3.6  4.3  24.444995  23.379238  0.088321
# 7       27      3  3.6  4.3  27.675996  23.276772  0.295267
# 8       24      3  3.6  4.3  25.498289  23.513055  0.093439
# 9       25      3  3.6  4.3  25.982037  23.380124  0.101843

# %%
# Show features' distribution graph
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'tem'}>,
#         <AxesSubplot:title={'center':'mass'}>,
#         <AxesSubplot:title={'center':'n'}>,
#         <AxesSubplot:title={'center':'w'}>],
#        [<AxesSubplot:title={'center':'s'}>,
#         <AxesSubplot:title={'center':'sw'}>,
#         <AxesSubplot:title={'center':'e'}>,
#         <AxesSubplot:title={'center':'ew'}>],
#        [<AxesSubplot:title={'center':'floor'}>,
#         <AxesSubplot:title={'center':'ceiling'}>,
#         <AxesSubplot:title={'center':'n occ'}>,
#         <AxesSubplot:title={'center':'x'}>],
#        [<AxesSubplot:title={'center':'y'}>,
#         <AxesSubplot:title={'center':'MRT'}>,
#         <AxesSubplot:title={'center':'T'}>,
#         <AxesSubplot:title={'center':'V'}>]], dtype=object)

# %%
import seaborn as sn
import matplotlib.pyplot as plt

corrMatrix = df.corr()
plt.figure(figsize = (15,8))
sn.heatmap(corrMatrix, annot=True)
plt.show()
